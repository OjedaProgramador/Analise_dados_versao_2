# %%
import pandas as pd
BASE = pd.read_csv('employee_attrition.csv')
BASE.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Posso 'forçar' o Pandas a mostrar todas as colunas da base de dados

# %%
with pd.option_context('display.max_columns', None):
    display(BASE.head(5))
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
BASE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# ## Posso colocar mais de uma formatação no 'with'

# %%
with pd.option_context('float_format', '{:.2f}'.format, 'display.max_columns', None):
    display(BASE.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# min              1.00                     1.00       30.00            1.00
# 25%            491.25                     2.00       48.00            2.00
# 50%           1020.50                     3.00       66.00            3.00
# 75%           1555.75                     4.00       83.75            3.00
# max           2068.00                     4.00      100.00            4.00
#
#        JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# count   1470.00          1470.00        1470.00      1470.00
# mean       2.06             2.73        6502.93     14313.10
# std        1.11             1.10        4707.96      7117.79
# min        1.00             1.00        1009.00      2094.00
# 25%        1.00             2.00        2911.00      8047.00
# 50%        2.00             3.00        4919.00     14235.50
# 75%        3.00             4.00        8379.00     20461.50
# max        5.00             4.00       19999.00     26999.00
#
#        NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count             1470.00            1470.00            1470.00
# mean                 2.69              15.21               3.15
# std                  2.50               3.66               0.36
# min                  0.00              11.00               3.00
# 25%                  1.00              12.00               3.00
# 50%                  2.00              14.00               3.00
# 75%                  4.00              18.00               3.00
# max                  9.00              25.00               4.00
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count                   1470.00        1470.00           1470.00
# mean                       2.71          80.00              0.79
# std                        1.08           0.00              0.85
# min                        1.00          80.00              0.00
# 25%                        2.00          80.00              0.00
# 50%                        3.00          80.00              1.00
# 75%                        4.00          80.00              1.00
# max                        4.00          80.00              3.00
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count            1470.00                1470.00          1470.00
# mean               11.28                   2.80             2.76
# std                 7.78                   1.29             0.71
# min                 0.00                   0.00             1.00
# 25%                 6.00                   2.00             2.00
# 50%                10.00                   3.00             3.00
# 75%                15.00                   3.00             3.00
# max                40.00                   6.00             4.00
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count         1470.00             1470.00                  1470.00
# mean             7.01                4.23                     2.19
# std              6.13                3.62                     3.22
# min              0.00                0.00                     0.00
# 25%              3.00                2.00                     0.00
# 50%              5.00                3.00                     1.00
# 75%              9.00                7.00                     3.00
# max             40.00               18.00                    15.00
#
#        YearsWithCurrManager
# count               1470.00
# mean                   4.12
# std                    3.57
# min                    0.00
# 25%                    2.00
# 50%                    3.00
# 75%                    7.00
# max                   17.00

# %% [markdown]
# ### Intervalo InterQuatis
#
# ### Subtração com o primeiro quartil
# ### Soma com o terceiro quartil
#
#     essas operações ocorrem para saber se existem 'outlaier':
#     se aparecer valores abaixo de 10,5 ou se aparecer valores acima de 62,5, serão considerados
#         'outlaier'

# %%
# esses dados foram retirados da coluna: age (idade)

quartil_1 = 30
quartil_3 = 43
intervalo = 1.5 * (quartil_3 - quartil_1)
print(f'O intervalo interquartil é de {intervalo}')

res = 30 - intervalo
print(res)

res_1 = 43 + intervalo
print(res_1)
# Out:
# O intervalo interquartil é de 19.5
# 10.5
# 62.5

# %%
BASE.describe(exclude='number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
BASE.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# ### Verificar linhas DUPLICADAS

# %%
BASE.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Exercícios da aula 25

# %%
BASE_NOVO = BASE.drop(['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'], axis=1)

# %% [markdown]
# ## Maiores valores, usa-se 'BASE_NOVO.nlargest(10, 'Age')'
#
# ## Menores valores, usa-se 'BASE_NOVO.nsmallest(10, 'Age')'

# %%
BASE_NOVO.nlargest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# 427                 28          3        Marketing                        3
# 536                 16          4        Marketing                        1
# 879                  7          4        Marketing                        2
# 1209                 1          4          Medical                        3
# 6                    3          3          Medical                        3
# 63                  25          3    Life Sciences                        1
# 70                   1          1    Life Sciences                        1
# 105                  2          4  Human Resources                        3
# 225                  3          3    Life Sciences                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 411   Female  ...                  3                         4
# 427   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
# 6     Female  ...                  4                         1
# 63    Female  ...                  3                         4
# 70    Female  ...                  3                         4
# 105   Female  ...                  4                         4
# 225     Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                33                      5
# 427                  0                22                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
# 6                    3                12                      3
# 63                   0                28                      3
# 70                   0                20                      2
# 105                  1                30                      3
# 225                  1                 7                      6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 411                1              29                   8
# 427                4              18                  13
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
# 6                  2               1                   0
# 63                 2              21                  16
# 70                 2               4                   3
# 105                3               3                   2
# 225                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 411                        11                   10
# 427                        13                   11
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
# 6                           0                    0
# 63                          7                    9
# 70                          1                    3
# 105                         2                    2
# 225                         0                    0
#
# [10 rows x 31 columns]

# %%
BASE_NOVO.nsmallest(10, 'YearsSinceLastPromotion')[['Age','JobRole','YearsSinceLastPromotion', 'JobLevel']]
# Out:
#     Age                JobRole  YearsSinceLastPromotion  JobLevel
# 0    41        Sales Executive                        0         2
# 2    37  Laboratory Technician                        0         1
# 6    59  Laboratory Technician                        0         1
# 7    30  Laboratory Technician                        0         1
# 10   35  Laboratory Technician                        0         1
# 11   29  Laboratory Technician                        0         2
# 14   28  Laboratory Technician                        0         1
# 16   32     Research Scientist                        0         1
# 17   22  Laboratory Technician                        0         1
# 21   36   Sales Representative                        0         1

# %%
BASE_NOVO.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
colunas_categoricas_nao_ordenada = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime',

]

colunas_categorias_ordenada = [
    'Education',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance',

]

coluna_alvo = ['Attrition']

colunas_numericas = [ coluna for coluna in BASE_NOVO.columns if coluna not in colunas_categoricas_nao_ordenada + colunas_categorias_ordenada + coluna_alvo]

# %%
print(colunas_numericas)
print(colunas_categoricas_nao_ordenada)
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
# ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

# %%
for coluna in (colunas_categoricas_nao_ordenada + colunas_categorias_ordenada):
    print(f'{coluna}: {BASE_NOVO[coluna].unique()}')
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# EnvironmentSatisfaction: [2 3 4 1]
# JobSatisfaction: [4 2 3 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
for coluna in colunas_categoricas_nao_ordenada:
    BASE_NOVO[coluna] = BASE_NOVO[coluna].astype('category')
BASE_NOVO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   category
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   category
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   category
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(7), int64(23), object(1)
# memory usage: 287.0+ KB

# %%
BASE_NOVO['Attrition'].value_counts().plot(kind='bar', color = ['blue', 'orange']);

# %% [markdown]
# ## Agrupamento

# %%
BASE_NOVO.groupby(['Department', 'Attrition']).size()
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\1724441526.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   BASE_NOVO.groupby(['Department', 'Attrition']).size()
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %% [markdown]
# # Pivotar

# %%
BASE_NOVO.pivot_table(index='Department', columns='Attrition', aggfunc='size', fill_value=0)
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\1744664730.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   BASE_NOVO.pivot_table(index='Department', columns='Attrition', aggfunc='size', fill_value=0)
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %% [markdown]
# ## Crosstab é uma função do Pandas

# %%
pd.crosstab(BASE_NOVO['Department'], BASE_NOVO['Attrition'], margins=True,margins_name='Total', normalize='index').style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_3d43b_row0_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_3d43b_row0_col1 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_3d43b_row1_col0, #T_3d43b_row2_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_3d43b_row1_col1, #T_3d43b_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_3d43b_row3_col0 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_3d43b_row3_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# </style>
# <table id="T_3d43b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_3d43b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_3d43b_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d43b_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_3d43b_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_3d43b_row0_col1" class="data row0 col1" >0.190476</td>
#     </tr>
#     <tr>
#       <th id="T_3d43b_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_3d43b_row1_col0" class="data row1 col0" >0.861602</td>
#       <td id="T_3d43b_row1_col1" class="data row1 col1" >0.138398</td>
#     </tr>
#     <tr>
#       <th id="T_3d43b_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_3d43b_row2_col0" class="data row2 col0" >0.793722</td>
#       <td id="T_3d43b_row2_col1" class="data row2 col1" >0.206278</td>
#     </tr>
#     <tr>
#       <th id="T_3d43b_level0_row3" class="row_heading level0 row3" >Total</th>
#       <td id="T_3d43b_row3_col0" class="data row3 col0" >0.838776</td>
#       <td id="T_3d43b_row3_col1" class="data row3 col1" >0.161224</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(BASE_NOVO['Department'], BASE_NOVO['Attrition'], margins=True, normalize='columns').style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d446c_row0_col0, #T_d446c_row0_col1, #T_d446c_row0_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d446c_row1_col0, #T_d446c_row1_col1, #T_d446c_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d446c_row2_col0 {
#   background-color: #9cce66;
#   color: #000000;
# }
# #T_d446c_row2_col1 {
#   background-color: #56ab66;
#   color: #f1f1f1;
# }
# #T_d446c_row2_col2 {
#   background-color: #92c866;
#   color: #000000;
# }
# </style>
# <table id="T_d446c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_d446c_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_d446c_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_d446c_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d446c_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_d446c_row0_col0" class="data row0 col0" >0.041363</td>
#       <td id="T_d446c_row0_col1" class="data row0 col1" >0.050633</td>
#       <td id="T_d446c_row0_col2" class="data row0 col2" >0.042857</td>
#     </tr>
#     <tr>
#       <th id="T_d446c_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_d446c_row1_col0" class="data row1 col0" >0.671533</td>
#       <td id="T_d446c_row1_col1" class="data row1 col1" >0.561181</td>
#       <td id="T_d446c_row1_col2" class="data row1 col2" >0.653741</td>
#     </tr>
#     <tr>
#       <th id="T_d446c_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_d446c_row2_col0" class="data row2 col0" >0.287105</td>
#       <td id="T_d446c_row2_col1" class="data row2 col1" >0.388186</td>
#       <td id="T_d446c_row2_col2" class="data row2 col2" >0.303401</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(BASE_NOVO['Department'], BASE_NOVO['Attrition']).plot(kind='bar', color=['blue', 'orange']);

# %% [markdown]
# ## Agrupamento por 'Departamento' !!!!

# %%
BASE_NOVO.groupby('Department')['MonthlyIncome'].mean().plot(kind='bar', color=('blue', 'red'));
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\2724253228.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   BASE_NOVO.groupby('Department')['MonthlyIncome'].mean().plot(kind='bar', color=('blue', 'red'));

# %%
BASE_NOVO.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\693705398.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   BASE_NOVO.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
BASE_NOVO.pivot_table(index='Department', columns='Attrition',values='MonthlyIncome').style.background_gradient(cmap='RdYlGn', axis='columns')
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\1987236758.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   BASE_NOVO.pivot_table(index='Department', columns='Attrition',values='MonthlyIncome').style.background_gradient(cmap='RdYlGn', axis='columns')
# <style type="text/css">
# #T_b6342_row0_col0, #T_b6342_row1_col0, #T_b6342_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b6342_row0_col1, #T_b6342_row1_col1, #T_b6342_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6342">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_b6342_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_b6342_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6342_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_b6342_row0_col0" class="data row0 col0" >7345.980392</td>
#       <td id="T_b6342_row0_col1" class="data row0 col1" >3715.750000</td>
#     </tr>
#     <tr>
#       <th id="T_b6342_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_b6342_row1_col0" class="data row1 col0" >6630.326087</td>
#       <td id="T_b6342_row1_col1" class="data row1 col1" >4108.075188</td>
#     </tr>
#     <tr>
#       <th id="T_b6342_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_b6342_row2_col0" class="data row2 col0" >7232.240113</td>
#       <td id="T_b6342_row2_col1" class="data row2 col1" >5908.456522</td>
#     </tr>
#   </tbody>
# </table>

# %%
BASE_NOVO.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\4190294480.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   BASE_NOVO.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()
# JobRole                    JobLevel
# Healthcare Representative  1                    NaN
#                            2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
#                            5                    NaN
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
#                            4                    NaN
#                            5                    NaN
# Laboratory Technician      1            2854.590000
#                            2            4455.625000
#                            3            5998.000000
#                            4                    NaN
#                            5                    NaN
# Manager                    1                    NaN
#                            2                    NaN
#                            3           12233.000000
#                            4           16613.276596
#                            5           19183.976744
# Manufacturing Director     1                    NaN
#                            2            5612.755556
#                            3            9307.044444
#                            4           13383.000000
#                            5                    NaN
# Research Director          1                    NaN
#                            2                    NaN
#                            3           12721.571429
#                            4           16429.038462
#                            5           19204.807692
# Research Scientist         1            2827.649573
#                            2            4818.912281
#                            3            9724.000000
#                            4                    NaN
#                            5                    NaN
# Sales Executive            1                    NaN
#                            2            5800.884120
#                            3            9124.987342
#                            4           13202.500000
#                            5                    NaN
# Sales Representative       1            2506.723684
#                            2            3921.000000
#                            3                    NaN
#                            4                    NaN
#                            5                    NaN
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ## Posso transformar essas informações em um DataFrame

# %%
BASE_NOVO.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap='RdYlGn', axis='index')
# Out:
# C:\Users\livia\AppData\Local\Temp\ipykernel_17148\3539218715.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   BASE_NOVO.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap='RdYlGn', axis='index')
# <style type="text/css">
# #T_8da5a_row0_col0, #T_8da5a_row4_col0, #T_8da5a_row8_col0, #T_8da5a_row9_col0, #T_8da5a_row13_col0, #T_8da5a_row14_col0, #T_8da5a_row15_col0, #T_8da5a_row16_col0, #T_8da5a_row20_col0, #T_8da5a_row24_col0, #T_8da5a_row25_col0, #T_8da5a_row26_col0, #T_8da5a_row33_col0, #T_8da5a_row34_col0, #T_8da5a_row35_col0, #T_8da5a_row39_col0, #T_8da5a_row42_col0, #T_8da5a_row43_col0, #T_8da5a_row44_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8da5a_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_8da5a_row2_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_8da5a_row3_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_8da5a_row5_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_8da5a_row6_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_8da5a_row7_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_8da5a_row10_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_8da5a_row11_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_8da5a_row12_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_8da5a_row17_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_8da5a_row18_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_8da5a_row19_col0, #T_8da5a_row29_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8da5a_row21_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_8da5a_row22_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_8da5a_row23_col0 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_8da5a_row27_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_8da5a_row28_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_8da5a_row30_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_8da5a_row31_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_8da5a_row32_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_8da5a_row36_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_8da5a_row37_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_8da5a_row38_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_8da5a_row40_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8da5a_row41_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8da5a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8da5a_level0_col0" class="col_heading level0 col0" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8da5a_level0_row0" class="row_heading level0 row0" rowspan="5">Healthcare Representative</th>
#       <th id="T_8da5a_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_8da5a_row0_col0" class="data row0 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_8da5a_row1_col0" class="data row1 col0" >5865.346154</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_8da5a_row2_col0" class="data row2 col0" >9363.954545</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_8da5a_row3_col0" class="data row3 col0" >12973.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_8da5a_row4_col0" class="data row4 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level0_row5" class="row_heading level0 row5" rowspan="5">Human Resources</th>
#       <th id="T_8da5a_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_8da5a_row5_col0" class="data row5 col0" >2733.212121</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row6" class="row_heading level1 row6" >2</th>
#       <td id="T_8da5a_row6_col0" class="data row6 col0" >5563.461538</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row7" class="row_heading level1 row7" >3</th>
#       <td id="T_8da5a_row7_col0" class="data row7 col0" >9623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_8da5a_row8_col0" class="data row8 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row9" class="row_heading level1 row9" >5</th>
#       <td id="T_8da5a_row9_col0" class="data row9 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level0_row10" class="row_heading level0 row10" rowspan="5">Laboratory Technician</th>
#       <th id="T_8da5a_level1_row10" class="row_heading level1 row10" >1</th>
#       <td id="T_8da5a_row10_col0" class="data row10 col0" >2854.590000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row11" class="row_heading level1 row11" >2</th>
#       <td id="T_8da5a_row11_col0" class="data row11 col0" >4455.625000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row12" class="row_heading level1 row12" >3</th>
#       <td id="T_8da5a_row12_col0" class="data row12 col0" >5998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row13" class="row_heading level1 row13" >4</th>
#       <td id="T_8da5a_row13_col0" class="data row13 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row14" class="row_heading level1 row14" >5</th>
#       <td id="T_8da5a_row14_col0" class="data row14 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level0_row15" class="row_heading level0 row15" rowspan="5">Manager</th>
#       <th id="T_8da5a_level1_row15" class="row_heading level1 row15" >1</th>
#       <td id="T_8da5a_row15_col0" class="data row15 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row16" class="row_heading level1 row16" >2</th>
#       <td id="T_8da5a_row16_col0" class="data row16 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row17" class="row_heading level1 row17" >3</th>
#       <td id="T_8da5a_row17_col0" class="data row17 col0" >12233.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row18" class="row_heading level1 row18" >4</th>
#       <td id="T_8da5a_row18_col0" class="data row18 col0" >16613.276596</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row19" class="row_heading level1 row19" >5</th>
#       <td id="T_8da5a_row19_col0" class="data row19 col0" >19183.976744</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level0_row20" class="row_heading level0 row20" rowspan="5">Manufacturing Director</th>
#       <th id="T_8da5a_level1_row20" class="row_heading level1 row20" >1</th>
#       <td id="T_8da5a_row20_col0" class="data row20 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_8da5a_row21_col0" class="data row21 col0" >5612.755556</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_8da5a_row22_col0" class="data row22 col0" >9307.044444</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row23" class="row_heading level1 row23" >4</th>
#       <td id="T_8da5a_row23_col0" class="data row23 col0" >13383.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row24" class="row_heading level1 row24" >5</th>
#       <td id="T_8da5a_row24_col0" class="data row24 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level0_row25" class="row_heading level0 row25" rowspan="5">Research Director</th>
#       <th id="T_8da5a_level1_row25" class="row_heading level1 row25" >1</th>
#       <td id="T_8da5a_row25_col0" class="data row25 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row26" class="row_heading level1 row26" >2</th>
#       <td id="T_8da5a_row26_col0" class="data row26 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8da5a_level1_row27" class="row_heading level1 row27" >3</th>
#       <td id="T_8da5a_row27_col0" class="data row27 col0" >12721.571429</td>
#     </tr>
#     <tr>
#       <th i

# %%
BASE_NOVO.pivot_table(
    index=['JobRole', 'JobLevel'], 
    columns='Attrition',
    values='MonthlyIncome', observed=False
    ).style.background_gradient(cmap='RdYlGn', axis='columns')
# Out:
# <style type="text/css">
# #T_09b8e_row0_col0, #T_09b8e_row1_col1, #T_09b8e_row2_col1, #T_09b8e_row3_col1, #T_09b8e_row4_col0, #T_09b8e_row4_col1, #T_09b8e_row5_col0, #T_09b8e_row6_col1, #T_09b8e_row7_col0, #T_09b8e_row8_col1, #T_09b8e_row9_col0, #T_09b8e_row10_col0, #T_09b8e_row10_col1, #T_09b8e_row11_col0, #T_09b8e_row12_col1, #T_09b8e_row13_col0, #T_09b8e_row14_col0, #T_09b8e_row14_col1, #T_09b8e_row15_col0, #T_09b8e_row15_col1, #T_09b8e_row16_col0, #T_09b8e_row16_col1, #T_09b8e_row17_col0, #T_09b8e_row18_col1, #T_09b8e_row19_col1, #T_09b8e_row20_col0, #T_09b8e_row20_col1, #T_09b8e_row21_col0, #T_09b8e_row22_col0, #T_09b8e_row23_col0, #T_09b8e_row24_col1, #T_09b8e_row25_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_09b8e_row0_col1, #T_09b8e_row1_col0, #T_09b8e_row2_col0, #T_09b8e_row3_col0, #T_09b8e_row5_col1, #T_09b8e_row6_col0, #T_09b8e_row7_col1, #T_09b8e_row8_col0, #T_09b8e_row9_col1, #T_09b8e_row11_col1, #T_09b8e_row12_col0, #T_09b8e_row13_col1, #T_09b8e_row17_col1, #T_09b8e_row18_col0, #T_09b8e_row19_col0, #T_09b8e_row21_col1, #T_09b8e_row22_col1, #T_09b8e_row23_col1, #T_09b8e_row24_col0, #T_09b8e_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09b8e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_09b8e_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_09b8e_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09b8e_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_09b8e_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_09b8e_row0_col0" class="data row0 col0" >5828.280000</td>
#       <td id="T_09b8e_row0_col1" class="data row0 col1" >6792.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_09b8e_row1_col0" class="data row1 col0" >9426.282051</td>
#       <td id="T_09b8e_row1_col1" class="data row1 col1" >8877.800000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_09b8e_row2_col0" class="data row2 col0" >13073.500000</td>
#       <td id="T_09b8e_row2_col1" class="data row2 col1" >12169.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_09b8e_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_09b8e_row3_col0" class="data row3 col0" >2871.260870</td>
#       <td id="T_09b8e_row3_col1" class="data row3 col1" >2415.700000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_09b8e_row4_col0" class="data row4 col0" >5563.461538</td>
#       <td id="T_09b8e_row4_col1" class="data row4 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_09b8e_row5_col0" class="data row5 col0" >9326.500000</td>
#       <td id="T_09b8e_row5_col1" class="data row5 col1" >10216.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_09b8e_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_09b8e_row6_col0" class="data row6 col0" >2921.708333</td>
#       <td id="T_09b8e_row6_col1" class="data row6 col1" >2682.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_09b8e_row7_col0" class="data row7 col0" >4394.000000</td>
#       <td id="T_09b8e_row7_col1" class="data row7 col1" >5084.200000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_09b8e_row8_col0" class="data row8 col0" >6306.500000</td>
#       <td id="T_09b8e_row8_col1" class="data row8 col1" >5381.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_09b8e_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_09b8e_row9_col0" class="data row9 col0" >12133.700000</td>
#       <td id="T_09b8e_row9_col1" class="data row9 col1" >12729.500000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_09b8e_row10_col0" class="data row10 col0" >16613.276596</td>
#       <td id="T_09b8e_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_09b8e_row11_col0" class="data row11 col0" >19159.575000</td>
#       <td id="T_09b8e_row11_col1" class="data row11 col1" >19509.333333</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_09b8e_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_09b8e_row12_col0" class="data row12 col0" >5644.870588</td>
#       <td id="T_09b8e_row12_col1" class="data row12 col1" >5066.800000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_09b8e_row13_col0" class="data row13 col0" >9262.400000</td>
#       <td id="T_09b8e_row13_col1" class="data row13 col1" >9664.200000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_09b8e_row14_col0" class="data row14 col0" >13383.000000</td>
#       <td id="T_09b8e_row14_col1" class="data row14 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_09b8e_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_09b8e_row15_col0" class="data row15 col0" >12721.571429</td>
#       <td id="T_09b8e_row15_col1" class="data row15 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_09b8e_row16_col0" class="data row16 col0" >16429.038462</td>
#       <td id="T_09b8e_row16_col1" class="data row16 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_09b8e_row17_col0" class="data row17 col0" >19188.916667</td>
#       <td id="T_09b8e_row17_col1" class="data row17 col1" >19395.500000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_09b8e_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_09b8e_row18_col0" class="data row18 col0" >2859.455026</td>
#       <td id="T_09b8e_row18_col1" class="data row18 col1" >2694.066667</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_09b8e_row19_col0" class="data row19 col0" >4822.345455</td>
#       <td id="T_09b8e_row19_col1" class="data row19 col1" >4724.500000</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_09b8e_row20_col0" class="data row20 col0" >9724.000000</td>
#       <td id="T_09b8e_row20_col1" class="data row20 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_09b8e_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_09b8e_row21_col0" class="data row21 col0" >5760.218274</td>
#       <td id="T_09b8e_row21_col1" class="data row21 col1" >6023.416667</td>
#     </tr>
#     <tr>
#       <th id="T_09b8e_level1_row22" class="row_heading level1 row22" >3</th>

# %%
BASE_NOVO.pivot_table(
    index=['JobRole', 'JobLevel'], 
    columns='Attrition',
    values='MonthlyIncome', 
    observed=False,
    aggfunc=['mean', 'size']
    )
# Out:
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1
# Healthcare Representative 1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Human Resources           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Laboratory Technician     4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Manager                   1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Manufacturing Director    1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Research Director         1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Research Scientist        4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Executive           1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Representative      3                  NaN           NaN    0   0
#                           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0

# %% [markdown]
# ## Tem como sumir com as linhas que são NaN
#
# ### Se eu colocar apenas 'dropna' - irá sumir TODAS AS LINHAS QUE TENHAM NaN
# ### mas eu posso 'refinar' essa busca com: (how= 'all', subset=[('maen', 'No'), ('mean', 'Yes')])

# %%
BASE_NOVO.pivot_table(
    index=['JobRole', 'JobLevel'], 
    columns='Attrition',
    values='MonthlyIncome', 
    observed=False,
    aggfunc=['mean', 'size']
    ).dropna(how='all',subset=[('mean', 'No'),('mean', 'Yes')])
# Out:
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1

# %%
pd.crosstab(
    [BASE_NOVO['JobRole'], BASE_NOVO['JobLevel']],
    BASE_NOVO['Attrition'],
    normalize='index',
).style.background_gradient(cmap='RdYlGn', axis='columns', vmin=0,vmax=1)
# Out:
# <style type="text/css">
# #T_a1b40_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_a1b40_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_a1b40_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_a1b40_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_a1b40_row2_col0, #T_a1b40_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_a1b40_row2_col1, #T_a1b40_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a1b40_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_a1b40_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_a1b40_row4_col0, #T_a1b40_row10_col0, #T_a1b40_row14_col0, #T_a1b40_row15_col0, #T_a1b40_row16_col0, #T_a1b40_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a1b40_row4_col1, #T_a1b40_row10_col1, #T_a1b40_row14_col1, #T_a1b40_row15_col1, #T_a1b40_row16_col1, #T_a1b40_row20_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a1b40_row5_col0, #T_a1b40_row8_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_a1b40_row5_col1, #T_a1b40_row8_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_a1b40_row6_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_a1b40_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_a1b40_row7_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_a1b40_row7_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_a1b40_row9_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_a1b40_row9_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_a1b40_row11_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_a1b40_row11_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_a1b40_row12_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_a1b40_row12_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_a1b40_row17_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_a1b40_row17_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_a1b40_row18_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_a1b40_row18_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_a1b40_row19_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_a1b40_row19_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_a1b40_row21_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_a1b40_row21_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_a1b40_row22_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_a1b40_row22_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_a1b40_row23_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_a1b40_row23_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_a1b40_row24_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_a1b40_row24_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a1b40_row25_col0 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_a1b40_row25_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1b40">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_a1b40_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a1b40_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1b40_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_a1b40_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_a1b40_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_a1b40_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_a1b40_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_a1b40_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_a1b40_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_a1b40_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_a1b40_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_a1b40_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_a1b40_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_a1b40_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_a1b40_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_a1b40_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_a1b40_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_a1b40_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_a1b40_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_a1b40_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_a1b40_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_a1b40_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_a1b40_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_a1b40_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_a1b40_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_a1b40_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_a1b40_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_a1b40_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_a1b40_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_a1b40_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_a1b40_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_a1b40_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_a1b40_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_a1b40_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_a1b40_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_a1b40_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_a1b40_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_a1b40_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_a1b40_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_a1b40_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_a1b40_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1b40_level1_row16"

# %%
BASE_NOVO.groupby('Gender', observed=True)['Age'].mean()
# Out:
# Gender
# Female    37.329932
# Male      36.653061
# Name: Age, dtype: float64

# %% [markdown]
# #### Posso colocar em 'intervalo' ou faixa de idade com o método 'values_counts(bins=qual o intervalo que voce quer)

# %%
BASE_NOVO.groupby('Gender', observed=True)['Age'].value_counts(bins=10).sort_index()
# Out:
# Gender  Age
# Female  (17.956999999999997, 22.2]     25
#         (22.2, 26.4]                   32
#         (26.4, 30.6]                   89
#         (30.6, 34.8]                  108
#         (34.8, 39.0]                  117
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (47.4, 51.6]                   35
#         (51.6, 55.8]                   36
#         (55.8, 60.0]                   21
# Male    (17.956999999999997, 22.2]     32
#         (22.2, 26.4]                   73
#         (26.4, 30.6]                  135
#         (30.6, 34.8]                  157
#         (34.8, 39.0]                  180
#         (39.0, 43.2]                  106
#         (43.2, 47.4]                   75
#         (47.4, 51.6]                   57
#         (51.6, 55.8]                   41
#         (55.8, 60.0]                   26
# Name: count, dtype: int64

# %%
BASE_NOVO.groupby('Gender', observed=True)['Age'].plot(kind='hist', legend=True, alpha=0.5);
