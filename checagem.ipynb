# %%
import pandas as pd

# %%
BASA_df = pd.read_csv('cereal.csv')

# %%
BASA_df = BASA_df.rename(columns={'name': 'OJEDA'})

# %%
BASA_df
# Out:
#                         OJEDA mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ###  Do jeito abaixo 'head' é para mostrar as primeiras 5 linhas da base de dados.
# ###  Dentro do () pode colocar a quantidade de linhas que vc vai querer que aparece!!!

# %%
BASA_df.head(15)
# Out:
#                         OJEDA mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                 Apple Jacks   K    C       110        2    0     125    1.0
# 7                     Basic 4   G    C       130        3    2     210    2.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# ...

# %% [markdown]
# ### Tem o método 'tail' ou calda, que mostra as ulimas linhas, o mesmo ocorre com o parêntese, pode colocar a qutd de linhas que
#     irá aparecer

# %%
BASA_df.tail(15)
# Out:
#                         OJEDA mfr type  calories  protein  fat  sodium  fiber  \
# 62              Rice Krispies   K    C       110        2    0     290    0.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 66                     Smacks   K    C       110        2    1      70    1.0
# 67                  Special K   K    C       110        6    0     230    1.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69          Total Corn Flakes   G    C       110        2    1     200    0.0
# 70          Total Raisin Bran   G    C       140        3    1     190    4.0
# 71          Total Whole Grain   G    C       100        3    1     200    3.0
# 72                    Triples   G    C       110        2    1     250    0.0
# ...

# %% [markdown]
# 'shape' mostra quantas colunas e quantas linhas têm.

# %%
BASA_df.shape
# Out:
# (77, 16)

# %%
BASA_df.columns
# Out:
# Index(['OJEDA', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
colunas = BASA_df.columns
for item in colunas:
    print(item)
# Out:
# OJEDA
# mfr
# type
# calories
# protein
# fat
# sodium
# fiber
# carbo
# sugars
# potass
# vitamins
# shelf
# weight
# cups
# rating

# %%
BASA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OJEDA     77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 10.2+ KB

# %% [markdown]
# 'isnull' mostra valores que são nulos
# 'isnull().sum()' soma a qutd que valores nulos

# %%
BASA_df.isnull().sum()
# Out:
# OJEDA       0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# ### 'describe' dá informações mais detalhadas sobre a basa de dados

# %%
BASA_df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# Essa forma abaixo é para formatar a forma de visializaçao das informações

# %%
with pd.option_context('float_format', '{:.2f}'.format):
    display(BASA_df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     77.00    77.00 77.00   77.00  77.00  77.00   77.00   77.00
# mean     106.88     2.55  1.01  159.68   2.15  14.60    6.92   96.08
# std       19.48     1.09  1.01   83.83   2.38   4.28    4.44   71.29
# min       50.00     1.00  0.00    0.00   0.00  -1.00   -1.00   -1.00
# 25%      100.00     2.00  0.00  130.00   1.00  12.00    3.00   40.00
# 50%      110.00     3.00  1.00  180.00   2.00  14.00    7.00   90.00
# 75%      110.00     3.00  2.00  210.00   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating
# count     77.00  77.00   77.00 77.00   77.00
# mean      28.25   2.21    1.03  0.82   42.67
# std       22.34   0.83    0.15  0.23   14.05
# min        0.00   1.00    0.50  0.25   18.04
# 25%       25.00   1.00    1.00  0.67   33.17
# 50%       25.00   2.00    1.00  0.75   40.40
# ...

# %%
BASA_df.nunique()
# Out:
# OJEDA       77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       22
# sugars      17
# potass      36
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %% [markdown]
# Posso saber a qtda de uma valor específico, no caso abaixo é o valor -1.

# %%
(BASA_df.select_dtypes('number') == -1).sum()
# Out:
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
BASA_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Length: 77, dtype: bool

# %%
BASA_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
BASA_df['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: count, dtype: int64
